# %% [markdown]
# # Assignment 1 - DAX ESG dataset

# %% [markdown]
# ## This notebook
# This notebook is boiler plate code that can be re-used for loading the data.
#
# ## Interesting resources
# - Source of the "actions" dataset: [Bridging the Gap in ESG Measurement: Using NLP to Quantify Environmental, Social, and Governance Communication](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=4622514)
# - Source of the target "DAX ESG" dataset: [Detecting greenwashing signals through a comparison of ESG reports and public media](https://www.swisstext.org/wp-content/uploads/2023/09/Greenwashing.pdf )
# - Example sentiment analysis on DAX ESG dataset https://colab.research.google.com/drive/1TrBuB3BbI5oOskD4ht7aHaAYyporTR7n?usp=sharing
# - https://www.kaggle.com/datasets/equintel/dax-esg-media-dataset?resource=download

# %%
import pandas as pd

# %%
df = pd.read_pickle("https://media.githubusercontent.com/media/JosPolfliet/vlerick-mai-nlp-2023/main/DATA/esg_documents_for_dax_companies_with_scores_all.pkl")
df
# Out:
#                    company                                            content  \
# 0            Beiersdorf AG  Sustainability Highlight Report CARE BEYOND SK...
# 1      Deutsche Telekom AG  Corporate Responsibility Report 2021 2 Content...
# 2               Vonovia SE  VONOVIA SE SUSTAINABILITY REPORT 2021 =For a S...
# 3               Merck KGaA  Sustainability Report 2021 TABLE OF CONTENTS S...
# 4                      MTU  Our ideas and concepts FOR A SUSTAINABLE FUTUR...
# ...                    ...                                                ...
# 11543           Zalando SE  To reset your pass, please enter your email be...
# 11544           Zalando SE   Lo esencial: Materias primas: correlaciones e...
# 11545           Zalando SE  A look at the evolution of the fashion industr...
# 11546           Zalando SE  By clicking submit, you agree to share your em...
# 11547           Zalando SE  These venture bets on startups that `` returne...
#
#                     datatype        date           domain  \
# 0      sustainability_report  2021-03-31              NaN
# 1      sustainability_report  2021-03-31              NaN
# 2      sustainability_report  2021-03-31              NaN
# 3      sustainability_report  2021-03-31              NaN
# 4      sustainability_report  2020-03-31              NaN
# ...                      ...         ...              ...
# 11543                   tech  2021-07-12      pocketgamer
# 11544               business  2022-07-05   marketscreener
# 11545              thinktank  2021-05-11       cbinsights
# 11546                   tech  2022-05-23  techfundingnews
# 11547              thinktank  2021-06-09       cbinsights
#
#                                               esg_topics  internal symbol  \
# 0      ['CleanWater', 'GHGEmission', 'ProductLiabilit...         1    BEI
# 1      ['DataSecurity', 'Iso50001', 'GlobalWarming', ...         1    DTE
# 2      ['Whistleblowing', 'DataSecurity', 'Vaccine', ...         1    VNA
# 3      ['DataSecurity', 'DataMisuse', 'DrugResistance...         1    MRK
# 4      ['WorkLifeBalance', 'Corruption', 'AirQuality'...         1    MTX
# ...                                                  ...       ...    ...
# 11543  ['CustomerService', 'Meat', 'HumanCapital', 'T...         0    ZAL
# 11544                                ['WasteManagement']         0    ZAL
# 11545  ['CustomerService', 'Recruiting', 'Sustainable...         0    ZAL
# 11546  ['ClimateTech', 'Cybersecurity', 'CorporateCul...         0    ZAL
# 11547  ['Renumeration', 'Recruiting', 'HumanCapital',...         0    ZAL
#
#                                                    title  \
# 0                BeiersdorfAG Sustainability Report 2021
# 1           DeutscheTelekomAG Sustainability Report 2021
# 2                   VonoviaSE Sustainability Report 2021
# 3                   MerckKGaA Sustainability Report 2021
# 4              MTUAeroEngines Sustainability Report 2020
# ...                                                  ...
# 11543                  Pocket Gamer Connects Digital # 7
# 11544          Índices: ni Value ni Growth, ¡defensivos!
# 11545   The Future of Fashion: Technology & the Industry
# 11546        These are the top 10 EMEA VCs of 2022 — TFN
# 11547  The 45 Best VC Investments Of All Time & What ...
#
#                                                      url  mean_action_score  \
# 0                                                    NaN           0.883412
# 1                                                    NaN           0.663768
# 2                                                    NaN           0.429047
# 3                                                    NaN           0.679299
# 4                                                    NaN           0.682892
# ...                                                  ...                ...
# 11543  https://www.pocketgamer.biz/events/1636/pocket...           0.595652
# 11544  https://es.marketscreener.com/noticias/ultimas...           0.000032
# 11545  https://www.cbinsights.com/research/fashion-te...           0.996982
# 11546  https://techfundingnews.com/these-are-the-top-...           0.470160
# 11547  https://www.cbinsights.com/research/best-ventu...           0.336821
#
#        n_chunks  n_estimated_actions
# 0          25.0                 22.0
# 1         263.0                173.0
# 2         193.0                 79.0
# 3         210.0                142.0
# 4         102.0                 68.0
# ...         ...                  ...
# 11543      13.0                  8.0
# 11544       3.0                  0.0
# 11545      32.0                 32.0
# 11546       6.0                  2.0
# 11547      61.0                 18.0
#
# [11548 rows x 13 columns]
